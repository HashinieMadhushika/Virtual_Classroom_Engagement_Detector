# %% [markdown]
# <a href="https://colab.research.google.com/github/HashinieMadhushika/Virtual-Classroom-Engagement-Detector/blob/main/engagement_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()  # Upload the kaggle.json file here
# Out:
#      <input type="file" id="files-750ff2b9-5803-4d09-b0a6-7c0efaa2e60d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-750ff2b9-5803-4d09-b0a6-7c0efaa2e60d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions list
# Out:
# 401 Client Error: Unauthorized for url: https://www.kaggle.com/api/v1/competitions/list?page=1

# %%
# Test Kaggle API
# !kaggle datasets list
# Out:
# ref                                                                  title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# saidaminsaidaxmadov/chocolate-sales                                  Chocolate Sales                                         468320  2026-01-04 14:23:35.490000              0         92  1.0
# rockyt07/social-media-user-analysis                                  Social Media User Analysis                           247842357  2026-01-14 02:28:41.970000              0        109  1.0
# neurocipher/heartdisease                                             Heart Disease                                             3491  2025-12-11 15:29:14.327000           2114        374  1.0
# ...

# %%
# !kaggle datasets download -d fahadullaha/facial-emotion-recognition-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fahadullaha/facial-emotion-recognition-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# facial-emotion-recognition-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import os

# Define the path to the downloaded zip file
zip_file_path = 'facial-emotion-recognition-dataset.zip'

# Define the directory where you want to extract the contents
extract_dir = 'facial-emotion-recognition-dataset'

# Create the extraction directory if it doesn't exist
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f'Dataset extracted to: {extract_dir}')

# List the contents of the extracted directory to see the files
print('Contents of the extracted directory:')
for root, dirs, files in os.walk(extract_dir):
    for name in files:
        print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# Streaming output truncated to the last 5000 lines.
# facial-emotion-recognition-dataset/processed_data/fear/fear_aug00516.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_02671.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_02403.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_02168.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_01482.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_00944.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_aug01914.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_03070.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_aug00691.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_02407.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_01737.jpg
# facial-emotion-recognition-dataset/processed_data/fear/fear_aug01853.jpg
# ...
